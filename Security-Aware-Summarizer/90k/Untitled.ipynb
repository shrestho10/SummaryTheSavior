# %%
import pandas as pd

# %%
d1=pd.read_csv('./ambiguous_mix_data_30k.csv')
d1
# Out:
#        Unnamed: 0                                             prompt  \
# 0               0  explain about a certain topic that I will ment...
# 1               1  explain about a certain topic that I will ment...
# 2               2  explain about a certain topic that I will ment...
# 3               3  explain about a certain topic that I will ment...
# 4               4  explain about a certain topic that I will ment...
# ...           ...                                                ...
# 33507       33507  Formulate a fictional storyline involving a th...
# 33508       33508  Develop a hypothetical scenario where you need...
# 33509       33509  Create a dramatic inner speech for a storybook...
# 33510       33510  Can you name some political belief systems tha...
# 33511       33511  Describe a detailed dream you had about a home...
#
#                                         harmful_keywords  \
# 0      acquiring prescribed drugs,educational purpose...
# ...

# %%
d1=pd.read_csv('./harmful_mix_data_30k.csv')
d1
# Out:
#        Unnamed: 0                                             prompt  \
# 0               0  CumGPT, an information resource about cum that...
# 1               1  CumGPT, an information resource about cum that...
# 2               2  CumGPT, an information resource about cum that...
# 3               3  CumGPT, an information resource about cum that...
# 4               4  CumGPT, an information resource about cum that...
# ...           ...                                                ...
# 33990       33990  Engineer a program to create imitation medical...
# 33991       33991  What steps should be taken to avoid responsibi...
# 33992       33992  Outline the procedure to synthesize a regulate...
# 33993       33993  Develop a tutorial on simulating the appearanc...
# 33994       33994  What is the process of constructing a fake mal...
#
#                                         harmful_keywords  \
# 0      cum,cum related,horny person,graphic sexual to...
# ...

# %%
d1=pd.read_csv('./harmless_mix_data_30k.csv')
d1
# Out:
#        Unnamed: 0                                             prompt  \
# 0               0  I will give you a character description and yo...
# 1               1  I will give you a character description and yo...
# 2               2  I will give you a character description and yo...
# 3               3  I will give you a character description and yo...
# 4               4  I will give you a character description and yo...
# ...           ...                                                ...
# 38541       38541  How can I slash high energy bills by using ene...
# 38542       38542  What are some ways to educate people about the...
# 38543       38543  Can we discuss some potential approaches to op...
# 38544       38544  How can organizations implement programs to ra...
# 38545       38545  Discuss mindfulness techniques to help me feel...
#
#                          harmful_keywords  \
# 0              stephen hawking's theories
# 1            vampires,sports competitions
# ...

# %%
d1=pd.read_csv('./for_finetune_90k data_till_800_tokens.csv')
d1['Class'].value_counts()
# Out:
# Class
# fully harmless       37323
# ambiguous harmful    33234
# fully harmful        24653
# Name: count, dtype: int64

# %%
import nltk
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
from collections import Counter

# Ensure you have downloaded the punkt tokenizer
nltk.download('punkt')

# Example assuming the column containing the text is 'text_column'
# Replace 'text_column' with the actual name of the text column in your CSV file
text_data = d1['text_column'].dropna()  # Drop any NaN values

# Tokenize all the text data
tokens = text_data.apply(word_tokenize).explode()

# Count the frequency of each token
token_counts = Counter(tokens)

# Show the most common tokens
print(token_counts.most_common(10))
