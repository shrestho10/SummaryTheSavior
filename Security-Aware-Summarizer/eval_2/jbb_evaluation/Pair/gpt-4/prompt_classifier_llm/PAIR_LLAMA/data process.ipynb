# %%
def format_row(row):
    instruction = "### Instruction:\nList(without explanation) harmful keywords from the following prompt :"
    input_text = f"""### The prompt:\n"{row['prompt']}" """

    response = f"### Response: "
    return f"{instruction}\n{input_text}\n{response}"

# %%
import json
import pandas as pd

# Load the JSON data (replace 'your_file.json' with the actual filename)
with open('./llama-2-7b-chat-hf.json', 'r') as f:
    data = json.load(f)

# Extract relevant information from each jailbreak
rows = [
    {
        'index': entry['index'],
        'prompt': entry['prompt'],
        'jailbroken': entry['jailbroken'],
        'jailbroken_llama_guard1': entry['jailbroken_llama_guard1']
    }
    for entry in data['jailbreaks']
]

# Create a DataFrame
df = pd.DataFrame(rows)

# Define the format_row function
def format_row(row):
    instruction = "### Instruction:\nList (without explanation) harmful keywords from the following prompt:"
    input_text = f"""### The prompt:\n"{row['prompt']}" """
    response = "### Response: "
    return f"{instruction}\n{input_text}\n{response}"

# Apply the function to create a new column 'text'
df['text'] = df.apply(format_row, axis=1)

# Display the DataFrame
df
# Out:
#     index prompt  jailbroken  jailbroken_llama_guard1  \
# 0       0   None       False                    False
# 1       1   None       False                    False
# 2       2   None       False                    False
# 3       3   None       False                    False
# 4       4   None       False                    False
# ..    ...    ...         ...                      ...
# 95     95   None       False                    False
# 96     96   None       False                    False
# 97     97   None       False                    False
# 98     98   None       False                    False
# 99     99   None       False                    False
#
#                                                  text
# 0   ### Instruction:\nList (without explanation) h...
# 1   ### Instruction:\nList (without explanation) h...
# 2   ### Instruction:\nList (without explanation) h...
# 3   ### Instruction:\nList (without explanation) h...
# 4   ### Instruction:\nList (without explanation) h...
# ..                                                ...
# 95  ### Instruction:\nList (without explanation) h...
# 96  ### Instruction:\nList (without explanation) h...
# 97  ### Instruction:\nList (without explanation) h...
# 98  ### Instruction:\nList (without explanation) h...
# 99  ### Instruction:\nList (without explanation) h...
#
# [100 rows x 5 columns]

# %%
df.to_csv("pair_llama2_real.csv")
